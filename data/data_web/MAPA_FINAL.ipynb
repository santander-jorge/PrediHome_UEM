# %%
import pandas as pd
from keplergl import KeplerGl
import geopandas as gpd
import json

# %% [markdown]
# ### Importo los el csv de los pisos de alquiler.

# %%
df_alquiler = pd.read_csv('Alquileres_coordenas_limpio.csv', sep=';', header=0)
df_alquiler.head(2)
# Out:
#      Referencia Tipo_vivienda                Dirección                Barrio  \
# 0   2805-002380          Piso  Calle Francisco de Goya  Prado de Somosaguas
# 1   2805-002377          Piso             Calle Solano  Prado de Somosaguas
#
#              Distrito           Población  Superficie construida  \
# 0  Pozuelo de Alarcón  Pozuelo de Alarcón                    121
# 1  Pozuelo de Alarcón  Pozuelo de Alarcón                    225
#
#    Superficie útil  Superficie solar  Habitaciones  ...   PMZona PMm²Zona  \
# 0            121.0                 0             3  ...  4039.88    19.27
# 1            190.0                 0             4  ...  4039.88    19.27
#
#        RMP      RMH                                        Descripción  \
# 0  27167.0  86403.0  Ubicada en la primera planta, esta residencia ...
# 1  27167.0  86403.0  INMOBARALIA presenta una exclusiva oportunidad...
#
#                                        <img>Url_foto  \
# ...

# %% [markdown]
# ### Importo los el csv de los pisos en venta.

# %%
df_venta = pd.read_csv('Ventas_coordenas_limpio.csv', sep = ';', header=0)
df_venta.head(2)
# Out:
#            Referencia     Tipo_vivienda          Dirección  \
# 0        IF7146-P1739              Piso  Calle de Goya, 17
# 1   4501235-120920037  Casa unifamiliar          Lozoyuela
#
#                Barrio                       Distrito  \
# 0  Golf-El Carralero                     Majadahonda
# 1          Lozoyuela   Lozoyuela-Navas-Sieteiglesias
#
#                        Población  Superficie construida  Superficie útil  \
# 0                    Majadahonda                    139              NaN
# 1  Lozoyuela-Navas-Sieteiglesias                    315            125.0
#
#    Superficie solar  Habitaciones  ...     PMZona PMm²Zona    RMP    RMH  \
# 0                 0             3  ...  806473.17  3809.79  21248  66390
# 1               976             4  ...  246857.14  1397.97  11600  29083
#
#                                          Descripción  \
# 0  ¡Increíble oportunidad de adquirir un piso en ...
# 1  BREM GLOBAL INMOBILIARIA presenta esta LUMINOS...
#
# ...

# %% [markdown]
# ### Importo el archivo Geojson de la geometría de los distritos de madrid.

# %%
df_distritos = gpd.read_file('Distritos_de_Madrid.geojson')
df_distritos.head(2)
# Out:
#    FID      NOMBRE CODDISTRIT    SHAPE_area     SHAPE_len  \
# 0    1      Centro          1  5.231267e+06  10304.545144
# 1    2  Arganzuela          2  6.466406e+06  12834.885747
#
#                                             geometry
# 0  POLYGON ((-3.69316 40.40735, -3.69320 40.40720...
# 1  POLYGON ((-3.70389 40.40520, -3.70297 40.40506...

# %% [markdown]
# ### Importo el archivo de municipios y distritos de madrid

# %%
df_municipios = gpd.read_file('Municipios.geojson')
df_municipios
# Out:
#      FID D_R  CD_ZT208                 ZT208  SHAPE_Length  SHAPE_Area  \
# 0      1           1.0          Madrid-01-01      0.061371    0.000180
# 1      2           2.0          Madrid-01-02      0.078836    0.000171
# 2      3           3.0          Madrid-01-03      0.069709    0.000204
# 3      4           4.0          Madrid-02-01      0.058365    0.000139
# 4      5           5.0          Madrid-02-02      0.083086    0.000209
# ..   ...  ..       ...                   ...           ...         ...
# 203  204         204.0            Titulcia-1      0.181462    0.001070
# 204  205         205.0  Comarca de la Vega-4      0.385526    0.007018
# 205  206         206.0           Chinch+ n-1      0.641698    0.012250
# 206  207         207.0        Villaconejos-1      0.245542    0.003517
# 207  208         208.0   Colmenar de Oreja-1      0.773258    0.013349
#
#                                               geometry
# 0    MULTIPOLYGON (((-3.71224 40.43023, -3.71214 40...
# ...

# %% [markdown]
# ### Importo el archivo Geojson de las paradas de metro.

# %%
df_paradas =gpd.read_file('PARADAS DE METRO.geojson')
df_paradas.head(2)
# Out:
#    OBJECTID IDESTACION FECHAACTUAL  MODO CODIGOESTACION DENOMINACION  \
# 0         1       4_38    20150709     4             38    NOVICIADO
# 1         2      4_175    20150709     4            175     ESTRELLA
#
#   OBSERVACIONES SITUACION CODIGOCTMESTACIONREDMETRO CODIGOEMPRESA  ...  \
# 0          0211         I                        50          0211  ...
# 1          0915         I                       175          0915  ...
#
#   FECHAINICIO  FECHAFIN       X        Y GRADOACCESIBILIDAD SITUACIONCALLE  \
# 0    19930701      None  440100  4475360                  N           None
# 1    19930701      None  443960  4473846                  N           None
#
#   DENOMINACION_SAE INTERURBANOS_CODIGOEMT_CRTM INTERURBANOS_CODIGOEMT_EMPRESA  \
# 0             None                        None                           None
# 1             None                        None                           None
#
#                     geometry
# 0  POINT (-3.70742 40.42484)
# ...

# %% [markdown]
# ### Importo el acrhivo Geojson de las líneas de metro.

# %%
df_lineas = gpd.read_file('LINEAS.geojson')
df_lineas.head(2)
# Out:
#    OBJECTID              IDTRAMO FECHAACTUAL  MODO  CODIGOITINERARIO  \
# 0         1  4_336284_278__755_I    20150709     4            336284
# 1         2  4_336285_278__756_I    20150709     4            336285
#
#   CODIGOGESTIONLINEA NUMEROLINEAUSUARIO SENTIDO TIPOITINERARIO CODIGOESTACION  \
# 0                102                10b       1              1            278
# 1                102                10b       2              1            278
#
#    ...                             IDFTRAMO  CODIGOOBSERVACION  \
# 0  ...  4__10_B____1_IT_1_4_278__755_TI_I_7               None
# 1  ...  4__10_B____2_IT_1_4_278__756_TI_I_5               None
#
#    CODIGOSUBLINEA DENOMINACION_SAE   IDFLINEA      IDFITINERARIO IDFESTACION  \
# 0            None             None  4__10_B__  4__10_B____1_IT_1       4_278
# 1            None             None  4__10_B__  4__10_B____2_IT_1       4_278
#
#   IDFPOSTE   IDFANDEN                                           geometry
# ...

# %% [markdown]
# ### Importo el archivo CSV de atención médica.

# %%
df_sanidad=pd.read_csv('Atención médica.csv', sep='|', header=0)
df_sanidad.head(2)
# Out:
#    Unnamed: 0       PK                                             NOMBRE  \
# 0           0  5855213  Centro Concertado de adicciones (CCAD) Centro ...
# 1           1   134929  Centro Concertado de Atención a las Adicciones...
#
#                                  DESCRIPCION-ENTIDAD  \
# 0  El Centro concertado de adicciones Centro form...
# 1  El CCAD Cáritas que forma parte de la red del ...
#
#                                              HORARIO  \
# 0                 De lunes a viernes de 9 a 17 horas
# 1  De lunes a viernes mañanas de 9 a 14 horas, ta...
#
#                                         EQUIPAMIENTO  \
# 0  Valoración interdisciplinar del/de la paciente...
# 1  Valoración interdisciplinar del/de la paciente...
#
#                                           TRANSPORTE  \
# 0                Metro: Alonso Martínez, L4, L5, L10
# 1  Bus: 9, 73, N2Metro: Alfonso XIII (L4), Prospe...
#
#                 DESCRIPCION  ACCESIBILIDAD  \
# ...

# %% [markdown]
# ### Importo el archivo CSV de las bibliotecas de madrid.

# %%
df_bibliotecas = pd.read_csv('bibliotecas_madrid.csv', sep=';' , header=0)
df_bibliotecas.head(2)
# Out:
#       PK                                       NOMBRE DESCRIPCION-ENTIDAD  \
# 0  25526  Biblioteca Pública Antonio Mingote (Latina)                 NaN
# 1   1774     Biblioteca Pública Elena Fortún (Retiro)                 NaN
#
#                                              HORARIO    EQUIPAMIENTO  \
# 0  Apertura de lunes a sábado.   De lunes a viern...  Wifi gratuito.
# 1  Apertura de lunes a sábado.   De lunes a viern...  Wifi gratuito.
#
#                                           TRANSPORTE  \
# 0  Bus: 138, 17   Cercanías Renfe: Maestra Justa ...
# 1  Metro: Pacífico (líneas 1 y 6), Conde de Casal...
#
#                                       DESCRIPCION ACCESIBILIDAD  \
# 0  Lectura fácil, letra grande, audiodescripción.             1
# 1  Lectura fácil, letra grande, audiodescripción.             1
#
#                                          CONTENT-URL       NOMBRE-VIA  ...  \
# 0  http://www.madrid.es/sites/v/index.jsp?vgnextc...     RAFAEL FINAT  ...
# ...

# %% [markdown]
# ### Importo el archivo CSV de centros polideportivos.

# %%
df_polideportivos = pd.read_csv('centros_polideportivos.csv', sep=';' , header=0)
df_polideportivos.head(2)
# Out:
#          PK                                             NOMBRE  \
# 0      4707  Centro Deportivo Municipal  María Jesús Rosa (...
# 1  10183549               Centro Deportivo Municipal Alcántara
#
#   DESCRIPCION-ENTIDAD                                            HORARIO  \
# 0                 NaN  Horario de uso de las instalaciones deportivas...
# 1                 NaN  Horario de uso de las instalaciones deportivas...
#
#                                         EQUIPAMIENTO  \
# 0  Clases deportivas     Pre-infantiles (0 a 5 añ...
# 1  Clases y escuelas deportivas    Pre-infantiles...
#
#                                           TRANSPORTE DESCRIPCION  \
# 0  Metro: Barrio del Pilar , Peñagrande.   Bus: 4...         NaN
# 1  Metro: Lista, Manuel Becerra.  Bus: 21, 43, 53...         NaN
#
#   ACCESIBILIDAD                                        CONTENT-URL  \
# 0             1  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# ...

# %% [markdown]
# ### Importo el archivo CSV de colegios públicos

# %%
df_colegios = pd.read_csv('colegios-publicos_madrid.csv', sep=';', header=0)
df_colegios.head(2)
# Out:
#        PK                         NOMBRE DESCRIPCION-ENTIDAD HORARIO  \
# 0  176850  Colegio Público Adolfo Suárez                 NaN     NaN
# 1    5075  Colegio Público Agustina Díez                 NaN     NaN
#
#                                      EQUIPAMIENTO  \
# 0  Comedor - Horario ampliado - Planes de mejora.
# 1                      Comedor - Horario ampliado
#
#                                         TRANSPORTE  \
# 0                                         BUS: 174
# 1  METRO: Alto del Arenal BUS: 54 , 58 , 103 , 143
#
#                                          DESCRIPCION  ACCESIBILIDAD  \
# 0  ENSEÑANZAS: Segundo ciclo de E. Infantil - Pri...              0
# 1           ENSEÑANZA: Educación infantil - Primaria              0
#
#                                          CONTENT-URL  \
# 0  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 1  http://www.madrid.es/sites/v/index.jsp?vgnextc...
#
#                  NOMBRE-VIA  ...            DISTRITO COORDENADA-X  \
# ...

# %% [markdown]
# ### Importo el archivo CSV de los museos de madrid.

# %%
df_museos = pd.read_csv('museos_madrid.csv', sep=';', header=0)
df_museos.head(2)
# Out:
#         PK                          NOMBRE  \
# 0  4847190         Casa Museo Lope de Vega
# 1  4949641  Casita - Museo del Ratón Pérez
#
#                                  DESCRIPCION-ENTIDAD  \
# 0  'Mi casilla, mi quietud, mi g&amp;uuml;ertecil...
# 1  La Casita-Museo de Ratón Pérez, constituye un ...
#
#                                              HORARIO EQUIPAMIENTO  \
# 0  De martes a domingo, de 10 a 18 horas.  Cerrad...          NaN
# 1  Visitas:     Lunes: 11 a 14 horas.   Martes a ...          NaN
#
#                                           TRANSPORTE  \
# 0  Metro: Antón Martín (línea 1), Sevilla (línea ...
# 1  Metro: Sol (líneas: 1, 2 y 3), Ópera (líneas 2...
#
#                                          DESCRIPCION ACCESIBILIDAD  \
# 0                                                NaN           0,4
# 1  Reserva de entradas presicialmente y a través ...             0
#
#                                          CONTENT-URL NOMBRE-VIA  ... DISTRITO  \
# ...

# %% [markdown]
# ### Importo el archivo CSV de universidades.

# %%
df_universidades = pd.read_csv('universidades-educacion.csv', sep=';', header=0)
df_universidades.head(2)
# Out:
#      PK                                             NOMBRE  \
# 0  6408     Centro de Enseñanza Superior Cardenal Cisneros
# 1  6368  Centro de Enseñanza Superior en Humanidades y ...
#
#   DESCRIPCION-ENTIDAD HORARIO EQUIPAMIENTO  \
# 0                 NaN     NaN          NaN
# 1                 NaN     NaN          NaN
#
#                                           TRANSPORTE  \
# 0  Metro: Lista (línea 4), Núñez de Balboa (línea...
# 1  Metro: Francos Rodríguez (línea 7).  Bus: 64, 44.
#
#                                          DESCRIPCION  ACCESIBILIDAD  \
# 0  Titulaciones   Psicología. Derecho. Administra...              3
# 1  Titulaciones   Grado de Maestro en Educación P...              3
#
#                                          CONTENT-URL            NOMBRE-VIA  \
# 0  http://www.madrid.es/sites/v/index.jsp?vgnextc...  GENERAL DIAZ PORLIER
# 1  http://www.madrid.es/sites/v/index.jsp?vgnextc...     MARIA AUXILIADORA
#
# ...

# %% [markdown]
# #### Creo el mapa con los datos.

# %%
config = {
    'version': 'v1',
    'config': {
        'mapState':{
            'latitude': 40.4167278,
            'longitude': -3.7033387,
            'zoom': 8
        }
    }
}

# %%
with open('configuracion_final.json', 'r') as j:
    configuracion = json.load(j)
type(configuracion)
# Out:
# dict

# %%
mapa = KeplerGl(show_docs=False, config=configuracion)
mapa.add_data(data=df_alquiler, name='VIVIENDAS EN ALQUILER')
mapa.add_data(data=df_venta, name='VIVIENDAS EN VENTA')
mapa.add_data(data=df_distritos, name='DISTRITOS DE MADRID')
mapa.add_data(data=df_municipios, name='MUNICIPIOS')
mapa.add_data(data=df_paradas, name='PARADAS DE METRO')
mapa.add_data(data=df_lineas, name='LINEAS DE METRO')
mapa.add_data(data=df_sanidad, name='ATENCIÓN MÉDICA')
mapa.add_data(data=df_bibliotecas, name='BIBLIOTECAS')
mapa.add_data(data=df_polideportivos, name='POLIDEPORTIVOS')
mapa.add_data(data=df_colegios, name='COLEGIOS')
mapa.add_data(data=df_museos, name='MUSEOS')
mapa.add_data(data=df_universidades, name='CENTROS DE ENSEÑANZA SUPERIOR')
mapa
# Out:
# C:\Users\raulm\AppData\Roaming\Python\Python311\site-packages\jupyter_client\session.py:721: UserWarning: Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#   content = self.pack(content)
# C:\Users\raulm\AppData\Roaming\Python\Python311\site-packages\jupyter_client\session.py:721: UserWarning: Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#   content = self.pack(content)
# C:\Users\raulm\AppData\Roaming\Python\Python311\site-packages\jupyter_client\session.py:721: UserWarning: Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
# ...

# %%
# with open('configuracion_final.json', 'w') as file:
#     json.dump(mapa.config, file, indent=4, sort_keys=True)

# %%
# mapa.save_to_html(file_name='MAPA DE VIVIENDAS COMUNIDAD DE MADRID.html')
